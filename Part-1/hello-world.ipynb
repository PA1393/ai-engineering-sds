# %% [markdown]
# ### Import the libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
OPENAPI_API_KEY = os.getenv("OPENAPI_API_KEY")

# %% [markdown]
# ### Step 2: Call the API

# %%
client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "user", 
        "content": "What are you"},
    ],
)

answer = response.choices[0].message.content 

print(answer)
# Out:
# I'm sorry, but I can't determine the question you just asked because I don't have the ability to recall previous interactions or access past data. Could you please repeat your question?
