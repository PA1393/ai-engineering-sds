# %% [markdown]
# ### call client completions without help

# %% [markdown]
# import openai from OpenAI
# import os
# import Ipython from display
#
# load_dotenv()
# OPENAPI_API_KEY = env("OPENAPI_API_KEY)
#
# client = load_dotenv()
#
# response = client.chat.completions.create(
#     model = 'gpt-4.5-mini'
#     response = [{'role': 'system', 'content': 'You are helpful assistant} + {'role': 'user', 'content': 'What is the capital of France?}]
# )
#
# reply = response[0].get(content)
# display(markdown(reply))
